# %%
import numpy as np
import pandas as pd
from collections import Counter

# %%
df = pd.read_csv('data.csv')

# %% [markdown]
# ## Exploration

# %%
df.head()
# Out:
#    Unnamed: 0  Clothing ID  Age                    Title  \
# 0           0          767   33                      NaN
# 1           1         1080   34                      NaN
# 2           2         1077   60  Some major design flaws
# 3           3         1049   50         My favorite buy!
# 4           4          847   47         Flattering shirt
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name
# 0                        0       Initmates        Intimate  Intimates
# 1                        4         General         Dresses    Dresses
# 2                        0         General         Dresses    Dresses
# 3                        0  General Petite         Bottoms      Pants
# 4                        6         General            Tops    Blouses

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23486 entries, 0 to 23485
# Data columns (total 11 columns):
# Unnamed: 0                 23486 non-null int64
# Clothing ID                23486 non-null int64
# Age                        23486 non-null int64
# Title                      19676 non-null object
# Review Text                22641 non-null object
# Rating                     23486 non-null int64
# Recommended IND            23486 non-null int64
# Positive Feedback Count    23486 non-null int64
# Division Name              23472 non-null object
# Department Name            23472 non-null object
# Class Name                 23472 non-null object
# dtypes: int64(6), object(5)
# memory usage: 2.0+ MB

# %%
df = df.dropna(axis=0, subset=['Review Text'])

# %%
df['Recommended IND'].value_counts()
# Out:
# 1    18540
# 0     4101
# Name: Recommended IND, dtype: int64

# %%
# we want a balanced dataset, hence we will undersample the positive review
df_positive = df[df['Recommended IND'] == 1].sample(4101)

# %%
df_negative = df[df['Recommended IND'] == 0]

# %%
df_2 = pd.concat([df_positive, df_negative])

# %%
positive_counts = Counter()
negative_counts = Counter()
total_counts = Counter()

# %%
for idx, row in df_2.iterrows():
    for word in row['Review Text'].split(' '):
        if row['Recommended IND'] == 1:
            positive_counts[word] += 1
            total_counts[word] += 1
        else:
            negative_counts[word] += 1
            total_counts[word] += 1

# %%
## common positive words?
positive_counts.most_common()
# Out:
# [('the', 12804),
#  ('and', 8944),
#  ('i', 8891),
#  ('a', 7914),
#  ('it', 6505),
#  ('is', 5551),
#  ('to', 4365),
#  ('this', 3682),
#  ('in', 3605),
#  ('but', 2777),
#  ('with', 2496),
#  ('for', 2474),
#  ('of', 2289),
#  ('on', 2285),
#  ('so', 2047),
#  ('my', 1932),
#  ('was', 1764),
#  ('that', 1641),
#  ('I', 1548),
#  ('not', 1526),
#  ('dress', 1438),
#  ('love', 1436),
#  ('very', 1384),
#  ('have', 1380),
#  ('are', 1367),
#  ('size', 1275),
#  ('be', 1222),
#  ('wear', 1184),
#  ("it's", 1182),
#  ('as', 1178),
#  ('like', 1149),
#  ('or', 1118),
#  ('am', 1058),
#  ('fit', 1050),
#  ('just', 927),
#  ("i'm", 925),
#  ('you', 884),
#  ('great', 883),
#  ('they', 874),
#  ('top', 836),
#  ('too', 836),
#  ('would', 809),
#  ('This', 804),
#  ('at', 796),
#  ('little', 738),
#  ('up', 722),
#  ('more', 697),
#  ('will', 676),
#  ('really', 665),
#  ('me', 663),
#  ('ordered', 650),
#  ('fabric', 641),
#  ('can', 639),
#  ('if', 628),
#  ('color', 606),
#  ('because', 597),
#  ('an', 584),
#  ('one', 577),
#  ('fits', 566),
#  ('than', 562),
#  ('bought', 554),
#  ('bit', 547),
#  ('look', 538),
#  ('', 536),
#  ('perfect', 533),
#  ('small', 528),
#  ('these', 525),
#  ('it.', 520),
#  ('had', 501),
#  ('looks', 498),
#  ('when', 493),
#  ('nice', 493),
#  ('has', 489),
#  ('which', 467),
#  ('-', 449),
#  ('soft', 449),
#  ('got', 428),
#  ('out', 421),
#  ('all', 394),
#  ('think', 391),
#  ('them', 378),
#  ('about', 376),
#  ('length', 376),
#  ('well', 373),
#  ('usually', 372),
#  ('comfortable', 367),
#  ('other', 367),
#  ('much', 359),
#  ('flattering', 358),
#  ('tried', 355),
#  ('only', 351),
#  ('long', 351),
#  ('cute', 350),
#  ('also', 344),
#  ('beautiful', 344),
#  ('material', 342),
#  ('medium', 337),
#  ('back', 332),
#  ('petite', 328),
#  ('super', 325),
#  ('could', 323),
#  ('from', 322),
#  ('even', 319),
#  ('get', 318),
#  ('down', 315),
#  ('true', 314),
#  ('colors', 306),
#  ('shirt', 305),
#  ('sweater', 304),
#  ('black', 295),
#  ("don't", 293),
#  ('quality', 288),
#  ('good', 284),
#  ('do', 283),
#  ('runs', 281),
#  ('right', 281),
#  ('pretty', 281),
#  ('jeans', 280),
#  ('store', 279),
#  ('see', 276),
#  ('still', 276),
#  ('feel', 275),
#  ('does', 275),
#  ('wearing', 271),
#  ('dress.', 269),
#  ('retailer', 263),
#  ('large', 262),
#  ('skirt', 262),
#  ('work', 262),
#  ('purchased', 260),
#  ('xs', 259),
#  ('go', 257),
#  ('waist', 255),
#  ('me.', 254),
#  ('some', 254),
#  ("didn't", 248),
#  ('no', 245),
#  ('enough', 244),
#  ('definitely', 238),
#  ('top.', 234),
#  ('made', 234),
#  ('how', 232),
#  ('were', 230),
#  ('size.', 229),
#  ('sleeves', 226),
#  ('there', 224),
#  ('way', 223),
#  ('Love', 223),
#  ('cut', 219),
#  ('did', 219),
#  ('many', 215),
#  ('over', 211),
#  ('pants', 209),
#  ('worn', 209),
#  ('short', 208),
#  ('it!', 206),
#  ('run', 204),
#  ('white', 201),
#  ('need', 198),
#  ('your', 197),
#  ('being', 197),
#  ('saw', 196),
#  ('makes', 195),
#  ('without', 194),
#  ('regular', 192),
#  ('style', 191),
#  ('around', 189),
#  ('try', 186),
#  ("can't", 185),
#  ('want', 185),
#  ('summer', 184),
#  ('been', 184),
#  ('light', 184),
#  ('tight', 184),
#  ('slightly', 183),
#  ('perfect.', 182),
#  ('design', 182),
#  ('blue', 181),
#  ('find', 180),
#  ('went', 178),
#  ("doesn't", 178),
#  ('online', 178),
#  ('going', 177),
#  ('big', 176),
#  ('small.', 175),
#  ('loved', 173),
#  ('both', 173),
#  ('make', 173),
#  ('found', 169),
#  ('what', 168),
#  ('flattering.', 168),
#  ('looking', 167),
#  ('casual', 166),
#  ('pair', 165),
#  ('wore', 163),
#  ('may', 162),
#  ('front', 162),
#  ('high', 162),
#  ('wish', 159),
#  ('its', 159),
#  ('normally', 158),
#  ('looked', 157),
#  ('however,', 157),
#  ('order', 156),
#  ('by', 156),
#  ('off', 156),
#  ('most', 155),
#  ('after', 155),
#  ('fall', 153),
#  ('thought', 152),
#  ('received', 152),
#  ('first', 152),
#  ('absolutely', 152),
#  ('usual', 152),
#  ('down.', 151),
#  ('sure', 150),
#  ('The', 150),
#  ('&', 150),
#  ('sale', 150),
#  ('loose', 149),
#  ('bottom', 149),
#  ('recommend', 146),
#  ('2', 146),
#  ('comfortable.', 146),
#  ('buy', 146),
#  ('on.', 144),
#  ('it,', 144),
#  ('piece', 144),
#  ('perfectly.', 144),
#  ('quite', 144),
#  ('though', 144),
#  ('longer', 143),
#  ('any', 143),
#  ('better', 142),
#  ('fit.', 142),
#  ('different', 142),
#  ('well.', 140),
#  ('while', 137),
#  ('body', 137),
#  ('color.', 136),
#  ('easy', 135),
#  ('great.', 134),
#  ('feels', 134),
#  ('probably', 134),
#  ('6', 133),
#  ('happy', 133),
#  ('jacket', 132),
#  ('say', 131),
#  ('weight', 130),
#  ('lovely', 130),
#  ('glad', 130),
#  ("i've", 129),
#  ('since', 129),
#  ('large.', 128),
#  ('dressed', 128),
#  ('4', 128),
#  ('another', 127),
#  ('price', 126),
#  ('might', 124),
#  ('compliments', 123),
#  ('pattern', 123),
#  ('side', 123),
#  ('wait', 122),
#  ('actually', 121),
#  ('through', 121),
#  ('under', 120),
#  ('s', 120),
#  ('shoulders', 120),
#  ('jeans.', 120),
#  ('detail', 119),
#  ('two', 119),
#  ('extra', 119),
#  ('lot', 118),
#  ('print', 118),
#  ('time', 118),
#  ('worth', 117),
#  ('then', 117),
#  ('lace', 117),
#  ('bra', 117),
#  ('between', 116),
#  ('wanted', 116),
#  ('keep', 116),
#  ('gorgeous', 116),
#  ('fitted', 116),
#  ('into', 115),
#  ('dresses', 115),
#  ('almost', 114),
#  ('always', 113),
#  ('bust', 113),
#  ('give', 112),
#  ('tops', 112),
#  ('decided', 112),
#  ('chest', 112),
#  ('full', 110),
#  ('arms', 108),
#  ('unique', 107),
#  ('thin', 107),
#  ("wasn't", 107),
#  ('smaller', 105),
#  ('These', 105),
#  ('shape', 105),
#  ('above', 104),
#  ('should', 103),
#  ('green', 103),
#  ('every', 103),
#  ('tank', 102),
#  ('up.', 102),
#  ("i'd", 102),
#  ('perfectly', 102),
#  ('dress,', 102),
#  ('top,', 102),
#  ('something', 101),
#  ('especially', 101),
#  ('comfy', 100),
#  ('person', 99),
#  ('skinny', 99),
#  ('leggings', 98),
#  ('shorter', 98),
#  ('sized', 98),
#  ('dress!', 97),
#  ('seems', 97),
#  ('model', 97),
#  ('felt', 96),
#  ('soft,', 96),
#  ('me,', 96),
#  ('nicely', 95),
#  ('(i', 94),
#  ('put', 94),
#  ('overall', 93),
#  ('too.', 93),
#  ('reviews', 93),
#  ('sizing', 92),
#  ("isn't", 92),
#  ('same', 91),
#  ('now', 91),
#  ('favorite', 91),
#  ('out.', 91),
#  ('lbs', 91),
#  ('stretch', 90),
#  ('comfortable,', 90),
#  ('yet', 89),
#  ('neck', 88),
#  ('such', 88),
#  ('few', 88),
#  ('size,', 87),
#  ('back.', 87),
#  ('wide', 87),
#  ('blouse', 87),
#  ('fabric.', 86),
#  ('take', 86),
#  ('details', 86),
#  ('8', 85),
#  ('able', 85),
#  ('hits', 85),
#  ('liked', 85),
#  ('beautiful.', 84),
#  ("that's", 83),
#  ('day', 83),
#  ('waist.', 82),
#  ('came', 82),
#  ('tee', 82),
#  ('thick', 82),
#  ('knit', 82),
#  ('grey', 81),
#  ('dark', 81),
#  ('m', 81),
#  ('best', 81),
#  ("I'm", 80),
#  ('fun', 80),
#  ('normal', 80),
#  ('navy', 80),
#  ('hem', 80),
#  ('where', 80),
#  ('larger', 80),
#  ('kind', 80),
#  ('denim', 80),
#  ('soft.', 79),
#  ('new', 79),
#  ('easily', 79),
#  ('those', 79),
#  ('red', 79),
#  ('highly', 79),
#  ('know', 78),
#  ('store.', 78),
#  ('low', 78),
#  ('part', 78),
#  ('typically', 77),
#  ('big.', 77),
#  ('however', 77),
#  ('embroidery', 77),
#  ('pants.', 76),
#  ('everything', 76),
#  ('reviewers', 76),
#  ('sweater.', 76),
#  ('them.', 76),
#  ('spring', 75),
#  ('look.', 75),
#  ('ended', 75),
#  ('flowy', 74),
#  ("you're", 74),
#  ('cute.', 74),
#  ('buttons', 74),
#  ('colors.', 74),
#  ('return', 73),
#  ('underneath', 73),
#  ('hit', 73),
#  ("i'll", 73),
#  ('last', 73),
#  ('maybe', 73),
#  ('button', 73),
#  ('local', 72),
#  ('hard', 72),
#  ('never', 72),
#  ('lightweight', 72),
#  ('top!', 72),
#  ('model.', 72),
#  ('due', 71),
#  ('price.', 71),
#  ('person.', 71),
#  ('slip', 71),
#  ('sizes', 71),
#  ('show', 71),
#  ('works', 71),
#  ('cotton', 71),
#  ('flattering,', 71),
#  ('shirt.', 70),
#  ('lbs,', 70),
#  ('picture', 69),
#  ('warm', 69),
#  ('neckline', 69),
#  ('snug', 68),
#  ('waist,', 68),
#  ('sleeve', 68),
#  ('on,', 68),
#  ('although', 68),
#  ('took', 67),
#  ("couldn't", 67),
#  ('problem', 66),
#  ('once', 66),
#  ('summer.', 66),
#  ('thing', 66),
#  ('length.', 66),
#  ('fit,', 66),
#  ('skirt.', 66),
#  ('pockets', 65),
#  ('add', 65),
#  ('sold', 65),
#  ('fabric,', 65),
#  ('wear.', 64),
#  ('fitting', 64),
#  ('fell', 64),
#  ('color,', 64),
#  ('compliments.', 64),
#  ('style.', 64),
#  ('small,', 64),
#  ('extremely', 64),
#  ('jeans,', 63),
#  ('pink', 63),
#  ('reviewer', 63),
#  ('cami', 63),
#  ('figure', 63),
#  ('long.', 63),
#  ('goes', 63),
#  ('paired', 63),
#  ('belt', 63),
#  ('room', 63),
#  ("they're", 63),
#  ('medium.', 63),
#  ('fine', 62),
#  ('Great', 62),
#  ('pretty.', 62),
#  ('sheer', 62),
#  ('wash', 62),
#  ('getting', 62),
#  ('lining', 62),
#  ('come', 61),
#  ('purchase', 61),
#  ("wouldn't", 61),
#  ('feminine', 60),
#  ('said', 60),
#  ('exactly', 60),
#  ('0', 60),
#  ('trying', 59),
#  ('before', 59),
#  ('Very', 59),
#  ("won't", 59),
#  ('tall', 59),
#  ('plan', 59),
#  ('boxy', 58),
#  ('less', 58),
#  ('who', 58),
#  ('boots', 58),
#  ('arm', 58),
#  ('shorts', 58),
#  ('tunic', 58),
#  ('tts.', 57),
#  ('winter', 57),
#  ('someone', 57),
#  ('comes', 57),
#  ('10', 57),
#  ('curvy', 57),
#  ('xxs', 57),
#  ('material.', 56),
#  ('online.', 56),
#  ('versatile', 56),
#  ('nicely.', 56),
#  ('large,', 56),
#  ('she', 56),
#  ('keeping', 56),
#  ('needed', 56),
#  ("5'", 56),
#  ('great,', 56),
#  ('fall.', 55),
#  ('buying', 55),
#  ('area', 55),
#  ('agree', 55),
#  ('sometimes', 54),
#  ('--', 54),
#  ('xs.', 54),
#  ('below', 54),
#  ('stretchy', 53),
#  ('zipper', 53),
#  ('swing', 53),
#  ('cool', 53),
#  ('why', 53),
#  ('quality.', 53),
#  ('drapes', 53),
#  ('surprised', 53),
#  ('straps', 53),
#  ('away', 53),
#  ('hips', 53),
#  ('today', 53),
#  ('least', 52),
#  ('heavy', 52),
#  ('one.', 52),
#  ('layer', 52),
#  ('seem', 52),
#  ('5', 52),
#  ('legs', 52),
#  ('piece.', 52),
#  ('hoping', 52),
#  ('.', 52),
#  ('cardigan', 51),
#  ('vest', 51),
#  ('across', 51),
#  ('hangs', 51),
#  ('nice,', 51),
#  ('quality,', 51),
#  ("(i'm", 51),
#  ('adds', 51),
#  ('underneath.', 51),
#  ('year', 51),
#  ('nice.', 51),
#  ('anything', 50),
#  ('hot', 50),
#  ('lots', 50),
#  ('tie', 50),
#  ('gave', 50),
#  ('beautiful,', 50),
#  ('open', 50),
#  ('their', 49),
#  ('fine.', 49),
#  ('all.', 49),
#  ('use', 49),
#  ('ran', 49),
#  ('lined', 49),
#  ('tad', 48),
#  ('gives', 48),
#  ('things', 48),
#  ('work.', 48),
#  ('slim', 48),
#  ('tight.', 48),
#  ('perfect!', 47),
#  ('time.', 47),
#  ('reference,', 47),
#  ('pictured.', 47),
#  ('this.', 47),
#  ('though.', 47),
#  ('sale.', 47),
#  ('rather', 46),
#  ('beautifully', 46),
#  ('kept', 46),
#  ('inches', 46),
#  ('thicker', 46),
#  ('washed', 46),
#  ('type', 45),
#  ("there's", 45),
#  ('pull', 45),
#  ('already', 45),
#  ('straight', 45),
#  ('several', 45),
#  ('issue', 45),
#  ('returned', 44),
#  ('prefer', 44),
#  ('delicate', 44),
#  ('making', 44),
#  ('t', 44),
#  ('pilcro', 44),
#  ('right.', 44),
#  ('excited', 44),
#  ('line', 43),
#  ('complaint', 43),
#  ('cream', 43),
#  ('tts', 43),
#  ('knew', 43),
#  ('said,', 43),
#  ('boots.', 43),
#  ('somewhat', 43),
#  ('falls', 43),
#  ('depending', 43),
#  ('tights', 43),
#  ('purchase.', 43),
#  ('jacket.', 43),
#  ('way.', 43),
#  ('coat', 42),
#  ('classic', 42),
#  ('5\'5"', 42),
#  ('online,', 42),
#  ('incredibly', 42),
#  ('slight', 42),
#  ('years', 42),
#  ('often', 42),
#  ('dry', 42),
#  ('body.', 42),
#  ('throw', 42),
#  ('nude', 42),
#  ('l', 42),
#  ('orange', 42),
#  ('5\'4"', 42),
#  ('ankle', 42),
#  ('5\'3"', 41),
#  ('inch', 41),
#  ('adorable', 41),
#  ('myself', 41),
#  ('bigger', 41),
#  ('length,', 41),
#  ('reference', 41),
#  ('drape', 41),
#  ('wonderful', 41),
#  ('ordering', 41),
#  ('design.', 41),
#  ('up,', 41),
#  ('torso', 41),
#  ('unfortunately', 41),
#  ('lbs.', 41),
#  ('cozy', 41),
#  ('bright', 40),
#  ('simple', 40),
#  ('next', 40),
#  ('well,', 40),
#  ('heels', 40),
#  ('must', 40),
#  ('cute,', 40),
#  ('leggings.', 40),
#  ('tops.', 40),
#  ('skin', 40),
#  ('totally', 40),
#  ('tiny', 40),
#  ('night', 40),
#  ('picture.', 39),
#  ('short.', 39),
#  ('otherwise', 39),
#  ('photo', 39),
#  ('shoulders.', 39),
#  ('that.', 39),
#  ('store,', 39),
#  ('shoulder', 39),
#  ('either', 39),
#  ('worried', 39),
#  ('(and', 39),
#  ('xl', 39),
#  ('cannot', 39),
#  ('detailing', 38),
#  ('shown', 38),
#  ('higher', 38),
#  ('photo.', 38),
#  ('also,', 38),
#  ('petite.', 38),
#  ('knee', 38),
#  ('ivory', 38),
#  ('did.', 38),
#  ('collar', 38),
#  ('basic', 38),
#  ('day.', 38),
#  ('returning', 38),
#  ('wedding', 38),
#  ('made.', 38),
#  ('nothing', 38),
#  ('available', 38),
#  ('holes', 37),
#  ('retailer.', 37),
#  ('hope', 37),
#  ('athletic', 37),
#  ('hold', 37),
#  ('amount', 37),
#  ('version', 37),
#  ('days', 37),
#  ('until', 37),
#  ('neutral', 37),
#  ('ever', 37),
#  ('comfy.', 37),
#  ('colored', 37),
#  ('5\'6"', 37),
#  ('substantial', 36),
#  ('having', 36),
#  ('yellow', 36),
#  ('115', 36),
#  ('staple', 36),
#  ('hips.', 36),
#  ('shirts', 36),
#  ('long,', 36),
#  ('petite,', 36),
#  ('bottom.', 36),
#  ('zip', 36),
#  ('lovely.', 36),
#  ('gray', 36),
#  (',', 36),
#  ('cropped', 36),
#  ('baby', 35),
#  ('vibrant', 35),
#  ('rich', 35),
#  ('typical', 35),
#  ('forward', 35),
#  ('Beautiful', 35),
#  ('back,', 35),
#  ('jean', 35),
#  ('far', 35),
#  ('similar', 35),
#  ('bust.', 35),
#  ('3', 35),
#  ('others', 35),
#  ('instead', 35),
#  ('broad', 35),
#  ('during', 35),
#  ('pleased', 34),
#  ('worked', 34),
#  ('second', 34),
#  ('flows', 34),
#  ('hang', 34),
#  ('better.', 34),
#  ('read', 34),
#  ('addition', 34),
#  ('wardrobe.', 34),
#  ('live', 34),
#  ('dressy', 34),
#  ('form', 34),
#  ('down,', 34),
#  ('oversized', 33),
#  ('caught', 33),
#  ('mine', 33),
#  ('sleeves.', 33),
#  ('sides', 33),
#  ('love.', 33),
#  ('person,', 33),
#  ('shape.', 33),
#  ('amazing', 33),
#  ('26', 33),
#  ('is.', 33),
#  ('weather', 33),
#  ('jumpsuit', 33),
#  ('arrived', 33),
#  ('disappointed', 33),
#  ('deep', 33),
#  ('beautifully.', 33),
#  ('material,', 33),
#  ('touch', 33),
#  ('cover', 32),
#  ('much.', 32),
#  ('12', 32),
#  ('eye', 32),
#  ('front.', 32),
#  ('cold', 32),
#  ('thinking', 32),
#  ('5\'7"', 32),
#  ('her', 32),
#  ('pictured', 32),
#  ('baggy', 32),
#  ('expect', 32),
#  ('previous', 32),
#  ('pictures', 32),
#  ('end', 32),
#  ('off.', 32),
#  ('special', 32),
#  ('used', 32),
#  ('detail.', 32),
#  ('slimming', 32),
#  ('looser', 32),
#  ('layering', 32),
#  ("haven't", 32),
#  ('linen', 32),
#  ('though,', 32),
#  ('sale,', 32),
#  ('spot', 32),
#  ('colors,', 31),
#  ('flare', 31),
#  ('Cute', 31),
#  ('in.', 31),
#  ('bad', 31),
#  ('lower', 31),
#  ('couple', 31),
#  ('hourglass', 31),
#  ('appears', 31),
#  ('gotten', 31),
#  ('armholes', 31),
#  ('sheer.', 31),
#  ('chest.', 31),
#  ('expected.', 31),
#  ('area.', 31),
#  ('sandals', 31),
#  ('gold', 30),
#  ('overall,', 30),
#  ('along', 30),
#  ('soon', 30),
#  ('sort', 30),
#  ('finally', 30),
#  ('seemed', 30),
#  ('plus', 30),
#  ('hesitant', 30),
#  ('120', 30),
#  ('frame.', 30),
#  ('exchange', 30),
#  ('people', 30),
#  ('silk', 30),
#  ('clothes', 30),
#  ('mid', 30),
#  ('flattering!', 30),
#  ('roomy', 30),
#  ('white.', 30),
#  ('again', 30),
#  (':)', 29),
#  ('immediately', 29),
#  ('medium,', 29),
#  ('135', 29),
#  ('all,', 29),
#  ('jeans!', 29),
#  ('photos', 29),
#  ('amazing.', 29),
#  ('arms.', 29),
#  ('suit', 29),
#  ('covers', 29),
#  ('125', 29),
#  ('winter.', 29),
#  ('fact', 29),
#  ('great!', 29),
#  ('months', 29),
#  ('pencil', 29),
#  ('expected', 29),
#  ('itself', 29),
#  ('mind', 29),
#  ('short,', 29),
#  ('considering', 29),
#  ('stars', 29),
#  ('times', 29),
#  ('darker', 29),
#  ('based', 29),
#  ('As', 29),
#  ('bodice', 29),
#  ('fan', 29),
#  ('brand', 29),
#  ('interesting', 29),
#  ('style,', 29),
#  ('brown', 29),
#  ('texture', 29),
#  ('big,', 29),
#  ('meant', 28),
#  ('stylish', 28),
#  ('pounds', 28),
#  ('27', 28),
#  ('shade', 28),
#  ('clothing', 28),
#  ('justice.', 28),
#  ('too!', 28),
#  ('except', 28),
#  ('flat', 28),
#  ('cute!', 28),
#  ('peplum', 28),
#  ('believe', 28),
#  ('seam', 28),
#  ('wardrobe', 28),
#  ("aren't", 28),
#  ('versatile.', 28),
#  ('unique.', 28),
#  ('xs,', 28),
#  ('items', 28),
#  ('reason', 28),
#  ('price,', 28),
#  ('v', 28),
#  ('flares', 27),
#  ('feel.', 27),
#  ('gorgeous.', 27),
#  ('sexy', 27),
#  ('simply', 27),
#  ('huge', 27),
#  ('pretty,', 27),
#  ('home', 27),
#  ('chest,', 27),
#  ('good.', 27),
#  ('pants,', 27),
#  ('each', 27),
#  ('one,', 27),
#  ('recommend.', 27),
#  ('stunning', 27),
#  ('blouse.', 26),
#  ('transition', 26),
#  ('truly', 26),
#  ('embroidered', 26),
#  ('we', 26),
#  ('tops,', 26),
#  ('says', 26),
#  ('close', 26),
#  ('item', 26),
#  ('prettier', 26),
#  ('knee.', 26),
#  ('but,', 26),
#  ('Bought', 26),
#  ('figure.', 26),
#  ('curves', 26),
#  ('pulled', 26),
#  ('narrow', 26),
#  ('wool', 26),
#  ('subtle', 26),
#  ('black,', 26),
#  ('awesome', 26),
#  ('heels.', 26),
#  ('these.', 26),
#  ('casual.', 26),
#  ('appropriate', 26),
#  ('that,', 26),
#  ('sheer,', 26),
#  ('p', 26),
#  ('dresses.', 26),
#  ('work,', 25),
#  ('generally', 25),
#  ('here', 25),
#  ('So', 25),
#  ('waisted', 25),
#  ('our', 25),
#  ('side.', 25),
#  ('inside', 25),
#  ('belly', 25),
#  ('w', 25),
#  ('natural', 25),
#  ('motif', 25),
#  ('barely', 25),
#  ('fairly', 25),
#  ('beach', 25),
#  ('leg', 25),
#  ('certainly', 25),
#  ('5\'8"', 25),
#  ('early', 25),
#  ('reading', 25),
#  ('5\'4",', 25),
#  ('5\'2"', 25),
#  ('leather', 25),
#  ('adore', 25),
#  ('for.', 25),
#  ('skirts', 25),
#  ('own', 25),
#  ('hip', 25),
#  ('flow', 25),
#  ('through.', 25),
#  ('consider', 24),
#  ('5\'9"', 24),
#  ('cut,', 24),
#  ('frame', 24),
#  ('spring.', 24),
#  ('Absolutely', 24),
#  ('heavier', 24),
#  ('wrong', 24),
#  ('this!', 24),
#  ("I've", 24),
#  ('ok', 24),
#  ('rise', 24),
#  ('trim', 24),
#  ('women', 24),
#  ('bit.', 24),
#  ('relaxed', 24),
#  ('t-shirt', 24),
#  ('Just', 24),
#  ('elastic', 24),
#  ('noticed', 24),
#  ('taller', 24),
#  ('perhaps', 24),
#  ('party', 24),
#  ('comfy,', 24),
#  ('bust,', 24),
#  ('shoulders,', 24),
#  ('busty', 24),
#  ('upper', 24),
#  ('flowers', 23),
#  ('stand', 23),
#  ('out,', 23),
#  ('finding', 23),
#  ('gorgeous!', 23),
#  ('past', 23),
#  ('warm.', 23),
#  ('easily.', 23),
#  ('half', 23),
#  ('hide', 23),
#  ('(not', 23),
#  ...]

# %%
negative_counts.most_common()
# Out:
# [('the', 15661),
#  ('i', 8752),
#  ('and', 8111),
#  ('it', 7496),
#  ('a', 6802),
#  ('is', 4797),
#  ('to', 4546),
#  ('was', 4137),
#  ('this', 4036),
#  ('in', 3701),
#  ('but', 3498),
#  ('on', 2885),
#  ('of', 2851),
#  ('not', 2367),
#  ('for', 2318),
#  ('so', 2020),
#  ('my', 1799),
#  ('I', 1792),
#  ('that', 1672),
#  ('like', 1671),
#  ('have', 1551),
#  ('very', 1531),
#  ('dress', 1470),
#  ('with', 1400),
#  ('too', 1369),
#  ('would', 1304),
#  ('be', 1258),
#  ('just', 1224),
#  ('top', 1155),
#  ('as', 1153),
#  ('are', 1107),
#  ('fit', 1079),
#  ('at', 1046),
#  ('fabric', 986),
#  ('size', 947),
#  ("it's", 922),
#  ('look', 886),
#  ('am', 874),
#  ('had', 868),
#  ('if', 861),
#  ('love', 855),
#  ('you', 838),
#  ('really', 835),
#  ('me', 807),
#  ('they', 795),
#  ('ordered', 793),
#  ("i'm", 761),
#  ('when', 720),
#  ('wear', 675),
#  ('it.', 675),
#  ('an', 668),
#  ('This', 659),
#  ('much', 653),
#  ('or', 633),
#  ('because', 625),
#  ('more', 608),
#  ('small', 597),
#  ('were', 597),
#  ('looks', 594),
#  ('than', 593),
#  ('even', 585),
#  ('me.', 582),
#  ('material', 579),
#  ('looked', 579),
#  ('up', 569),
#  ('out', 557),
#  ('back', 548),
#  ("didn't", 547),
#  ('one', 533),
#  ('way', 533),
#  ('color', 517),
#  ('shirt', 507),
#  ('', 496),
#  ('also', 496),
#  ('will', 485),
#  ('all', 478),
#  ('from', 466),
#  ('-', 457),
#  ('tried', 453),
#  ('which', 452),
#  ('made', 450),
#  ('wanted', 446),
#  ('could', 445),
#  ('there', 435),
#  ('these', 426),
#  ('no', 415),
#  ('did', 409),
#  ('quality', 402),
#  ('going', 392),
#  ('great', 391),
#  ('back.', 374),
#  ('cute', 374),
#  ('has', 371),
#  ('work', 369),
#  ('sweater', 366),
#  ('little', 360),
#  ('other', 350),
#  ('cut', 349),
#  ('get', 346),
#  ('loved', 336),
#  ('thought', 335),
#  ('see', 335),
#  ('been', 333),
#  ('good', 331),
#  ('them', 331),
#  ('think', 329),
#  ('large', 327),
#  ('The', 317),
#  ('however,', 314),
#  ("don't", 309),
#  ('short', 308),
#  ('nice', 308),
#  ('usually', 307),
#  ('about', 306),
#  ('beautiful', 304),
#  ('waist', 304),
#  ('pretty', 301),
#  ('what', 297),
#  ('retailer', 296),
#  ('bit', 293),
#  ('design', 290),
#  ('got', 284),
#  ('bought', 281),
#  ('dress.', 279),
#  ('felt', 275),
#  ('still', 273),
#  ('big', 272),
#  ('flattering', 271),
#  ('down', 267),
#  ('return', 264),
#  ('runs', 261),
#  ('after', 253),
#  ('only', 252),
#  ('do', 248),
#  ('sleeves', 247),
#  ('can', 242),
#  ('petite', 241),
#  ('skirt', 240),
#  ('colors', 239),
#  ('thin', 237),
#  ('tight', 236),
#  ('well', 236),
#  ('front', 235),
#  ('xs', 235),
#  ('right', 235),
#  ('long', 232),
#  ('your', 231),
#  ('does', 229),
#  ('length', 229),
#  ('try', 227),
#  ('wearing', 226),
#  ('around', 226),
#  ('disappointed', 223),
#  ('excited', 222),
#  ('top.', 222),
#  ('first', 221),
#  ('how', 220),
#  ('off', 217),
#  ('high', 216),
#  ('bottom', 210),
#  ('over', 210),
#  ('make', 208),
#  ('better', 206),
#  ('returned', 203),
#  ('soft', 203),
#  ('then', 201),
#  ('style', 200),
#  ('looking', 198),
#  ("doesn't", 198),
#  ('feel', 197),
#  ('model', 197),
#  ('online', 195),
#  ('shape', 193),
#  ('super', 193),
#  ('medium', 193),
#  ("wasn't", 191),
#  ('on.', 190),
#  ('by', 188),
#  ('pants', 188),
#  ('two', 185),
#  ('go', 185),
#  ('maybe', 185),
#  ('returning', 183),
#  ('arms', 182),
#  ('body', 181),
#  ('both', 177),
#  ('unfortunately', 177),
#  ('some', 177),
#  ('found', 172),
#  ('chest', 168),
#  ('store', 167),
#  ('put', 167),
#  ('small.', 166),
#  ('white', 166),
#  ('it,', 164),
#  ('purchased', 162),
#  ('definitely', 162),
#  ('bust', 161),
#  ("couldn't", 159),
#  ('sure', 157),
#  ('huge', 156),
#  ('price', 156),
#  ("can't", 155),
#  ('quite', 155),
#  ('perfect', 153),
#  ('fits', 152),
#  ('someone', 151),
#  ('might', 151),
#  ('shoulders', 151),
#  ('makes', 150),
#  ('saw', 148),
#  ('while', 148),
#  ('something', 147),
#  ('wide', 146),
#  ('since', 146),
#  ('however', 146),
#  ('dress,', 145),
#  ('under', 143),
#  ('cheap', 142),
#  ('pattern', 142),
#  ('same', 142),
#  ('reviews', 142),
#  ('flattering.', 141),
#  ('received', 141),
#  ('side', 140),
#  ('fit.', 140),
#  ('loose', 140),
#  ('through', 139),
#  ('went', 138),
#  ('smaller', 137),
#  ('black', 137),
#  ('should', 137),
#  ('where', 136),
#  ('wore', 136),
#  ('boxy', 136),
#  ('washed', 134),
#  ('another', 134),
#  ('time', 133),
#  ('me,', 133),
#  ('such', 132),
#  ('true', 132),
#  ('worth', 132),
#  ('almost', 132),
#  ('top,', 132),
#  ('blouse', 131),
#  ('any', 131),
#  ('its', 130),
#  ('picture', 129),
#  ('liked', 129),
#  ('fabric.', 128),
#  ('keep', 128),
#  ('2', 127),
#  ('came', 126),
#  ('need', 125),
#  ('part', 125),
#  ('blue', 125),
#  ('though', 125),
#  ('extra', 125),
#  ('want', 125),
#  ('on,', 125),
#  ('all.', 125),
#  ('may', 124),
#  ('normally', 124),
#  ('size.', 123),
#  ('lot', 122),
#  ('&', 122),
#  ('seemed', 121),
#  ("isn't", 120),
#  ('extremely', 119),
#  ('being', 119),
#  ('also,', 118),
#  ('unfortunately,', 118),
#  ('arm', 118),
#  ('bra', 118),
#  ('off.', 117),
#  ('shorter', 117),
#  ('well.', 117),
#  ('usual', 116),
#  ('nothing', 116),
#  ('model.', 116),
#  ('wish', 116),
#  ('large.', 115),
#  ('overall', 113),
#  ('neck', 112),
#  ('sale', 112),
#  ('print', 112),
#  ('disappointed.', 112),
#  ('area', 111),
#  ('into', 109),
#  ('find', 109),
#  ('actually', 109),
#  ('problem', 109),
#  ('regular', 109),
#  ('enough', 108),
#  ('sizing', 107),
#  ('kind', 107),
#  ('without', 106),
#  ('few', 106),
#  ('6', 106),
#  ('different', 106),
#  ("i've", 106),
#  ('4', 106),
#  ('comfortable', 105),
#  ('price.', 105),
#  ('unflattering', 105),
#  ('probably', 105),
#  ('who', 105),
#  ('jeans', 103),
#  ('seems', 103),
#  ('person', 103),
#  ('most', 102),
#  ("wouldn't", 101),
#  ('sadly', 101),
#  ('buttons', 101),
#  ('order', 101),
#  ('especially', 101),
#  ('bad', 101),
#  ('sizes', 100),
#  ('completely', 100),
#  ('feels', 99),
#  ('holes', 99),
#  ('unflattering.', 99),
#  ('fitted', 99),
#  ('photo', 98),
#  ("i'd", 98),
#  ('color.', 98),
#  ('longer', 98),
#  ('absolutely', 97),
#  ('buy', 96),
#  ('hoping', 96),
#  ('fabric,', 95),
#  ('zipper', 94),
#  ('big.', 94),
#  ('pair', 94),
#  ('lace', 94),
#  ('give', 94),
#  ('ran', 94),
#  ('picture.', 94),
#  ('sized', 93),
#  ('hips', 93),
#  ('now', 93),
#  ('say', 92),
#  ('before', 92),
#  ('least', 92),
#  ('out.', 92),
#  ('across', 92),
#  ('online.', 92),
#  ('hit', 92),
#  ('quality.', 91),
#  ('trying', 91),
#  ('low', 91),
#  ('take', 90),
#  ('larger', 90),
#  ('between', 90),
#  ('huge.', 90),
#  ('once', 90),
#  ('jacket', 90),
#  ('light', 88),
#  ('work.', 88),
#  ('person.', 88),
#  ('run', 88),
#  ("that's", 87),
#  ('dresses', 87),
#  ('size,', 87),
#  ('arrived', 87),
#  ('tall', 86),
#  ('full', 86),
#  ('recommend', 86),
#  ('neckline', 86),
#  ('lovely', 86),
#  ('rather', 86),
#  ('thing', 86),
#  ('wash', 86),
#  ('many', 86),
#  ('tops', 84),
#  ('maternity', 84),
#  ('thick', 84),
#  ('small,', 84),
#  ('lay', 84),
#  ('hung', 83),
#  ('s', 83),
#  ('know', 83),
#  ('heavy', 83),
#  ('took', 82),
#  ('decided', 82),
#  ('expected', 82),
#  ('way.', 81),
#  ('them.', 81),
#  ('shirt.', 81),
#  ('odd', 80),
#  ('waist.', 80),
#  ("I'm", 80),
#  ('reviewers', 80),
#  ('cute,', 79),
#  ('already', 79),
#  ('short.', 79),
#  ('material.', 79),
#  ('never', 79),
#  ('slip', 78),
#  ('button', 78),
#  ('weird', 78),
#  ('every', 78),
#  ('beautiful,', 77),
#  ('why', 77),
#  ('down.', 77),
#  ('color,', 76),
#  ('lbs', 76),
#  ('idea', 74),
#  ('stiff', 74),
#  ('store.', 74),
#  ('fit,', 74),
#  ('piece', 73),
#  ('poor', 73),
#  ('suit', 73),
#  ('gorgeous', 73),
#  ('pull', 73),
#  ('sheer', 73),
#  ('reviewer', 73),
#  ('coat', 72),
#  ('red', 72),
#  ('their', 72),
#  ('(i', 72),
#  ('sad', 72),
#  ('returned.', 71),
#  ('inches', 71),
#  ('slightly', 71),
#  ('line', 71),
#  ('--', 71),
#  ('return.', 71),
#  ('worn', 71),
#  ('model,', 70),
#  ('kept', 70),
#  ('shown', 70),
#  ('normal', 70),
#  ('pretty,', 70),
#  ('said', 69),
#  ('great.', 69),
#  ('seem', 69),
#  ('sadly,', 69),
#  ('lining', 69),
#  ('above', 69),
#  ('below', 69),
#  ('shape.', 68),
#  ('making', 68),
#  ('8', 67),
#  ('barely', 67),
#  ('everything', 67),
#  ('up.', 67),
#  ('body.', 67),
#  ('fell', 66),
#  ("i'll", 66),
#  ('item', 65),
#  ('imagine', 65),
#  ('returning.', 65),
#  ('fine', 65),
#  ('knit', 65),
#  ('wide.', 65),
#  ('anything', 65),
#  ('ended', 65),
#  ('curvy', 65),
#  ('sides', 65),
#  ('chest.', 65),
#  ('cheap.', 64),
#  ('stretch', 63),
#  ('one.', 63),
#  ('flat', 63),
#  ('boxy.', 63),
#  ('although', 63),
#  ('hard', 63),
#  ('due', 63),
#  ('previous', 63),
#  ('this.', 63),
#  ('those', 63),
#  ('several', 62),
#  ("you're", 62),
#  ('detail', 62),
#  ('half', 61),
#  ('weight', 61),
#  ('10', 61),
#  ('hips.', 61),
#  ('agree', 61),
#  ('long.', 61),
#  ('retailer.', 61),
#  ('awkward', 60),
#  ('strange', 60),
#  ('online,', 60),
#  ('last', 60),
#  ('straight', 60),
#  ('summer', 60),
#  ('well,', 59),
#  ('fitting', 59),
#  ('based', 59),
#  ("there's", 59),
#  ('hopes', 58),
#  ('fall', 58),
#  ('come', 58),
#  ('upper', 58),
#  ('large,', 58),
#  ('sweater.', 58),
#  ('able', 58),
#  ('tank', 57),
#  ('pulled', 57),
#  ('m', 57),
#  ('seam', 57),
#  ('.', 57),
#  ('reference,', 56),
#  ('wrong', 56),
#  ('shoulder', 56),
#  ('read', 56),
#  ('unless', 56),
#  ('appears', 56),
#  ('5', 55),
#  ('type', 55),
#  ('front.', 55),
#  ('needed', 55),
#  ('right.', 55),
#  ('(and', 55),
#  ('typically', 54),
#  ('material,', 54),
#  ('this,', 54),
#  ('hem', 54),
#  ('belt', 54),
#  ('green', 54),
#  ('l', 54),
#  ('dry', 54),
#  ('day', 54),
#  ('photo.', 54),
#  ('frame.', 53),
#  ('3', 53),
#  ('must', 53),
#  ('underneath', 53),
#  ('end', 53),
#  ('less', 53),
#  ('baggy', 53),
#  ('sent', 53),
#  ('hole', 53),
#  ('thin,', 52),
#  ('adorable', 52),
#  ('hangs', 52),
#  ('figure', 52),
#  ('length.', 52),
#  ('pockets', 52),
#  ('perhaps', 52),
#  ('instead', 52),
#  ('always', 52),
#  ('away', 51),
#  ('show', 51),
#  ('design.', 51),
#  ('except', 51),
#  ('These', 51),
#  ('totally', 51),
#  ('lbs,', 51),
#  ('product', 51),
#  ('layer', 50),
#  ('used', 50),
#  ('photos', 50),
#  ('waist,', 50),
#  ('shows', 50),
#  ('others', 50),
#  ('nice,', 50),
#  ('past', 50),
#  ('style.', 50),
#  ('short,', 50),
#  ('either', 50),
#  ('tunic', 50),
#  ('better.', 49),
#  ('plus', 49),
#  ('bottom.', 49),
#  ('sort', 49),
#  ('bust.', 49),
#  (':(', 49),
#  ('having', 49),
#  ('real', 49),
#  ('flowy', 49),
#  ('immediately', 49),
#  ('back,', 49),
#  ('xl', 49),
#  ('look.', 48),
#  ('wear.', 48),
#  ('torso', 48),
#  ('soft,', 48),
#  ('second', 48),
#  ('lower', 48),
#  ('sleeve', 48),
#  ('tight.', 48),
#  ('Loved', 47),
#  ('issue', 47),
#  ('pictured', 47),
#  ('dark', 47),
#  ('incredibly', 47),
#  ('portion', 47),
#  ('ordering', 47),
#  ('shrunk', 47),
#  ('whole', 47),
#  ('legs', 47),
#  ('rest', 47),
#  ('though.', 47),
#  ('swimming', 46),
#  ('elastic', 46),
#  ('expected.', 46),
#  ('cute.', 46),
#  ('casual', 46),
#  ('use', 46),
#  ('bad.', 46),
#  ('far', 46),
#  ('embroidery', 46),
#  ('bulky', 46),
#  ('sending', 46),
#  ('pictures', 46),
#  ('xxs', 45),
#  ('send', 45),
#  ('thin.', 45),
#  ('swing', 45),
#  ('itself', 45),
#  ('pink', 45),
#  ('beautiful.', 45),
#  ('open', 45),
#  ('until', 45),
#  ('cotton', 45),
#  ('petite.', 44),
#  ('knew', 44),
#  ('shoulders.', 44),
#  ('bigger', 44),
#  ('xs.', 44),
#  ('area.', 44),
#  ('middle', 44),
#  ('you.', 44),
#  ('seams', 44),
#  ("they're", 44),
#  ('tie', 44),
#  ('expect', 44),
#  ('medium.', 43),
#  ('cami', 43),
#  ('shirt,', 43),
#  ('hourglass', 43),
#  ('pounds', 43),
#  ('tag', 43),
#  ('hits', 43),
#  ('room', 43),
#  ('through.', 43),
#  ('pants.', 43),
#  ('cold', 43),
#  ('price,', 43),
#  ('quality,', 43),
#  ('drape', 42),
#  ('keeping', 42),
#  ("(i'm", 42),
#  ('best', 42),
#  ('pictured.', 42),
#  ('washing', 42),
#  ('receive', 42),
#  ('anyone', 42),
#  ('point', 42),
#  ('great,', 42),
#  ('but,', 42),
#  ('pretty.', 42),
#  ('lined', 42),
#  ('wool', 41),
#  ('itchy', 41),
#  ('reference', 41),
#  ('things', 41),
#  ('too.', 41),
#  ('similar', 41),
#  ('much.', 41),
#  ('noticed', 41),
#  ('said,', 41),
#  ('times', 41),
#  ('along', 41),
#  ('goes', 41),
#  ('hand', 41),
#  ('ever', 41),
#  ('sewn', 40),
#  ('literally', 40),
#  ('shapeless', 40),
#  ('exactly', 40),
#  ('wait', 40),
#  ('armholes', 40),
#  ("5'", 40),
#  ('old', 40),
#  ('review', 40),
#  ('tell', 40),
#  ('collar', 40),
#  ('thinking', 40),
#  ('all,', 39),
#  ('else', 39),
#  ('worked', 39),
#  ('cut.', 39),
#  ('reviews.', 39),
#  ('person,', 39),
#  ('vibrant', 39),
#  ('brand', 39),
#  ('lbs.', 39),
#  ('purchase', 39),
#  ('tee', 39),
#  ('getting', 39),
#  ('hang', 39),
#  ('close', 39),
#  ('gave', 39),
#  ('peplum', 39),
#  ('unique', 39),
#  ('it!', 39),
#  ('three', 38),
#  ('left', 38),
#  ('narrow', 38),
#  ('cannot', 38),
#  ('arms.', 38),
#  ('bright', 38),
#  ('otherwise', 38),
#  ('It', 38),
#  ('stretched', 38),
#  ('style,', 38),
#  ('taller', 38),
#  ('skinny', 38),
#  ('nicely', 38),
#  ('fairly', 38),
#  ('local', 38),
#  ('time.', 38),
#  ('somewhat', 37),
#  ('higher', 37),
#  ('straps', 37),
#  ('petite,', 37),
#  ('her', 37),
#  ('appear', 37),
#  ('not.', 37),
#  ('easily', 37),
#  ('big,', 37),
#  ('t', 37),
#  ('Love', 37),
#  ('yet', 37),
#  ('tent', 37),
#  ('design,', 37),
#  ('nice.', 37),
#  ('slim', 37),
#  ('sale.', 37),
#  ('comfy', 37),
#  ('money', 37),
#  ('overall,', 36),
#  ('disappointing', 36),
#  ('tent.', 36),
#  ('falls', 36),
#  ('though,', 36),
#  ('yellow', 36),
#  ('expecting', 36),
#  ('surprised', 36),
#  ('needs', 36),
#  ('12', 36),
#  ('grey', 36),
#  ('buying', 36),
#  ('reviews,', 36),
#  ('oversized', 36),
#  ('up,', 35),
#  ('tad', 35),
#  ('perfectly', 35),
#  ('sack.', 35),
#  ('started', 35),
#  ('everywhere', 35),
#  ("would've", 35),
#  ('delicate', 35),
#  ('reading', 35),
#  ('believe', 35),
#  ('good.', 35),
#  ('details', 35),
#  ('stitching', 35),
#  ('mentioned', 34),
#  ('store,', 34),
#  ('tiny', 34),
#  ('snug', 34),
#  ('terrible', 34),
#  ('so,', 34),
#  ('chest,', 34),
#  ('new', 34),
#  ('busty', 34),
#  ("won't", 34),
#  ('denim', 34),
#  ('be.', 34),
#  ('mail', 34),
#  ('sweater,', 34),
#  ('pilcro', 34),
#  ('hold', 34),
#  ('athletic', 34),
#  ('xs,', 34),
#  ('lovely,', 34),
#  ('warm', 34),
#  ('zip', 33),
#  ('wider', 33),
#  ('months', 33),
#  ('arms,', 33),
#  ('sold', 33),
#  ('leggings', 33),
#  ('mind', 33),
#  ('opened', 33),
#  ('band', 33),
#  ('either.', 33),
#  ('5\'4"', 33),
#  ('bad,', 33),
#  ('frame', 33),
#  ('added', 33),
#  ('stretchy', 33),
#  ('today', 33),
#  ('comes', 33),
#  ('is.', 33),
#  ('120', 33),
#  ('stay', 32),
#  ('that.', 32),
#  ('near', 32),
#  ('again', 32),
#  ('sheer.', 32),
#  ('stripes', 32),
#  ('hanging', 32),
#  ('flares', 32),
#  ('shame', 32),
#  ('reason', 32),
#  ('colors.', 32),
#  ('poorly', 32),
#  ('favorite', 32),
#  ('soon', 32),
#  ('guess', 32),
#  ('people', 32),
#  ('0', 32),
#  ('fine,', 32),
#  ('fan', 32),
#  ('cover', 32),
#  ('sack', 32),
#  ('truly', 32),
#  ('forward', 32),
#  ('photo,', 32),
#  ('inside', 32),
#  ('them,', 32),
#  ('figure.', 32),
#  ('awful.', 32),
#  ('5\'5"', 31),
#  ('flattering,', 31),
#  ('scratchy', 31),
#  ('simply', 31),
#  ('So', 31),
#  ('for.', 31),
#  ('flatter', 31),
#  ('skin', 31),
#  ('given', 31),
#  ('amount', 31),
#  ('length,', 31),
#  ('cool', 31),
#  ('entire', 31),
#  ('leg', 31),
#  ('soft.', 31),
#  ('orange', 31),
#  ('darker', 31),
#  ('attached', 31),
#  ('happy', 31),
#  ('bust,', 31),
#  ('comfortable,', 31),
#  ('despite', 31),
#  ('thighs', 31),
#  ('fact', 30),
#  ('myself', 30),
#  ('easy', 30),
#  ('clothing', 30),
#  ('hip', 30),
#  ('gone', 30),
#  ('comfortable.', 30),
#  ('boxy,', 30),
#  ('that,', 30),
#  ('threads', 30),
#  ('shirts', 30),
#  ('photos.', 30),
#  ('130', 30),
#  ('shorts', 30),
#  ('medium,', 29),
#  ('package', 29),
#  ('next', 29),
#  ('5\'8"', 29),
#  ('summer.', 29),
#  ('says', 29),
#  ('picture,', 29),
#  ('sleeves.', 29),
#  ('against', 29),
#  ('maeve', 29),
#  ('made.', 29),
#  ('works', 29),
#  ('When', 29),
#  ('care', 29),
#  ('hips,', 29),
#  ('pant', 29),
#  ('arrived,', 29),
#  ('couple', 29),
#  ('description', 29),
#  ('odd.', 29),
#  ('disappointing.', 29),
#  ('water', 29),
#  ('frumpy', 29),
#  ('version', 29),
#  ('lightweight', 29),
#  ('5\'3"', 29),
#  ('pulling', 28),
#  ('difficult', 28),
#  ('gotten', 28),
#  ('one,', 28),
#  ('back!', 28),
#  ('skirt.', 28),
#  ('heavier', 28),
#  ('work,', 28),
#  (',', 28),
#  ('hope', 28),
#  ('retailer,', 28),
#  ('pants,', 28),
#  ('dresses.', 28),
#  ('dress!', 28),
#  ('xl.', 28),
#  ('she', 28),
#  ('apart', 28),
#  ('140', 28),
#  ('concept', 28),
#  ('loose,', 28),
#  ('flimsy', 27),
#  ('waistband', 27),
#  ('torso.', 27),
#  ('cropped', 27),
#  ('itchy.', 27),
#  ('gray', 27),
#  ('bag', 27),
#  ('basically', 27),
#  ('fine.', 27),
#  ('lost', 27),
#  ('waisted', 27),
#  ('interesting', 27),
#  ('piece.', 27),
#  ('pieces', 27),
#  ('supposed', 27),
#  ('billowy', 27),
#  ('considered', 27),
#  ('polyester', 27),
#  ('awful', 27),
#  ('knee', 27),
#  ('live', 27),
#  ('ripped', 27),
#  ('jumpsuit', 27),
#  ('home', 27),
#  ('b', 26),
#  ('cup', 26),
#  ('pleats', 26),
#  ('5\'4",', 26),
#  ('oddly', 26),
#  ('bodice', 26),
#  ('help', 26),
#  ('husband', 26),
#  ('like.', 26),
#  ('feeling', 26),
#  ('sizes.', 26),
#  ('taking', 26),
#  ('pilling', 26),
#  ('each', 26),
#  ('bottom,', 26),
#  ('mine', 26),
#  ('cut,', 26),
#  ('jeans,', 26),
#  ('As', 26),
#  ('generally', 26),
#  ('disappointment.', 25),
#  ('thread', 25),
#  ('navy', 25),
#  ('thicker', 25),
#  ('reminded', 25),
#  ('5\'2"', 25),
#  ('tops.', 25),
#  ('clothes', 25),
#  ('out,', 25),
#  ("It's", 25),
#  ('problem.', 25),
#  ('sit', 25),
#  ('slender', 25),
#  ('goes.', 25),
#  ('Beautiful', 25),
#  ('jeans.', 25),
#  ('sweatshirt', 25),
#  ('years', 25),
#  ('long,', 25),
#  ('5\'6"', 25),
#  ('blouse.', 25),
#  ('perfect.', 25),
#  ('lighter', 25),
#  ('showed', 25),
#  ('wash.', 25),
#  ('romper', 25),
#  ('spot', 25),
#  ('taken', 25),
#  ('own', 25),
#  ('broad', 25),
#  ('falling', 25),
#  ('finally', 24),
#  ('pinned', 24),
#  ('day.', 24),
#  ('worst', 24),
#  ('positive', 24),
#  ('thinner', 24),
#  ('coming', 24),
#  ('wide,', 24),
#  ('tall,', 24),
#  ('made,', 24),
#  ('showing', 24),
#  ('t-shirt', 24),
#  ...]

# %%
## ratios of words for their appearance in positive / in negative

pos_neg_ratios = Counter()

for term,count in list(total_counts.most_common()):
    if(count > 100):
        pos_neg_ratio = positive_counts[term] / float(negative_counts[term]+1)
        pos_neg_ratios[term] = pos_neg_ratio

# %%
pos_neg_ratios.most_common()
# Out:
# [('dressed', 21.333333333333332),
#  ('perfectly.', 10.285714285714286),
#  ('compliments', 9.461538461538462),
#  ('perfect.', 7.0),
#  ('glad', 5.909090909090909),
#  ('Love', 5.868421052631579),
#  ('it!', 5.15),
#  ('comfortable.', 4.709677419354839),
#  ('jeans.', 4.615384615384615),
#  ('easy', 4.354838709677419),
#  ('happy', 4.15625),
#  ('fits', 3.6993464052287583),
#  ('casual', 3.5319148936170213),
#  ('fun', 3.4782608695652173),
#  ('comfortable', 3.4622641509433962),
#  ('perfect', 3.461038961038961),
#  ('dress!', 3.3448275862068964),
#  ('navy', 3.076923076923077),
#  ('summer', 3.0163934426229506),
#  ('wait', 2.975609756097561),
#  ('worn', 2.9027777777777777),
#  ('leggings', 2.8823529411764706),
#  ('perfectly', 2.8333333333333335),
#  ('comfortable,', 2.8125),
#  ('favorite', 2.757575757575758),
#  ('jeans', 2.6923076923076925),
#  ('unique', 2.675),
#  ('comfy', 2.6315789473684212),
#  ('can', 2.6296296296296298),
#  ('fall', 2.593220338983051),
#  ('slightly', 2.5416666666666665),
#  ('skinny', 2.5384615384615383),
#  ('many', 2.471264367816092),
#  ('soft.', 2.46875),
#  ('nicely', 2.4358974358974357),
#  ('lightweight', 2.4),
#  ('details', 2.388888888888889),
#  ('true', 2.3609022556390977),
#  ('yet', 2.3421052631578947),
#  ('run', 2.292134831460674),
#  ('denim', 2.2857142857142856),
#  ('new', 2.257142857142857),
#  ('great', 2.252551020408163),
#  ('colors.', 2.242424242424242),
#  ('enough', 2.238532110091743),
#  ('flattering,', 2.21875),
#  ('too.', 2.2142857142857144),
#  ('soft', 2.200980392156863),
#  ('grey', 2.189189189189189),
#  ('black', 2.13768115942029),
#  ('always', 2.1320754716981134),
#  ('weight', 2.096774193548387),
#  ('easily', 2.0789473684210527),
#  ('light', 2.067415730337079),
#  ('tee', 2.05),
#  ('little', 2.044321329639889),
#  ('These', 2.019230769230769),
#  ('warm', 1.9714285714285715),
#  ('bought', 1.9645390070921986),
#  ('soft,', 1.9591836734693877),
#  ('piece', 1.945945945945946),
#  ('snug', 1.9428571428571428),
#  ('down.', 1.935897435897436),
#  ('hits', 1.9318181818181819),
#  ('great.', 1.9142857142857144),
#  ('detail', 1.8888888888888888),
#  ('best', 1.8837209302325582),
#  ('green', 1.8727272727272728),
#  ('bit', 1.8605442176870748),
#  ('size.', 1.846774193548387),
#  ('local', 1.8461538461538463),
#  ('beautiful.', 1.826086956521739),
#  ('without', 1.8130841121495327),
#  ('with', 1.7815845824411134),
#  ('or', 1.7634069400630914),
#  ('tank', 1.7586206896551724),
#  ('wear', 1.7514792899408285),
#  ('regular', 1.7454545454545454),
#  ('medium', 1.7371134020618557),
#  ('pair', 1.736842105263158),
#  ('pants.', 1.7272727272727273),
#  ('dark', 1.6875),
#  ('recommend', 1.6781609195402298),
#  ('love', 1.6775700934579438),
#  ('super', 1.675257731958763),
#  ('store', 1.6607142857142858),
#  ('being', 1.6416666666666666),
#  ('embroidery', 1.6382978723404256),
#  ('find', 1.6363636363636365),
#  ('length', 1.6347826086956523),
#  ('nice', 1.5954692556634305),
#  ('purchased', 1.5950920245398772),
#  ('cute.', 1.574468085106383),
#  ('well', 1.5738396624472575),
#  ('need', 1.5714285714285714),
#  ('gorgeous', 1.5675675675675675),
#  ('absolutely', 1.5510204081632653),
#  ('getting', 1.55),
#  ('cotton', 1.5434782608695652),
#  ('look.', 1.530612244897959),
#  ('order', 1.5294117647058822),
#  ('day', 1.509090909090909),
#  ('long', 1.5064377682403434),
#  ('buy', 1.5051546391752577),
#  ('most', 1.5048543689320388),
#  ('got', 1.5017543859649123),
#  ('up.', 1.5),
#  ('goes', 1.5),
#  ('lovely', 1.4942528735632183),
#  ('above', 1.4857142857142858),
#  ('flowy', 1.48),
#  ('want', 1.4682539682539681),
#  ('definitely', 1.460122699386503),
#  ('hem', 1.4545454545454546),
#  ('jacket', 1.4505494505494505),
#  ('longer', 1.4444444444444444),
#  ('pretty.', 1.441860465116279),
#  ('able', 1.4406779661016949),
#  ('blue', 1.4365079365079365),
#  ('cami', 1.4318181818181819),
#  ('room', 1.4318181818181819),
#  ('medium.', 1.4318181818181819),
#  ('s', 1.4285714285714286),
#  ('some', 1.4269662921348314),
#  ('say', 1.4086021505376345),
#  ('stretch', 1.40625),
#  ('typically', 1.4),
#  ("they're", 1.4),
#  ('m', 1.396551724137931),
#  ('will', 1.3909465020576133),
#  ('feel', 1.3888888888888888),
#  ('sleeve', 1.3877551020408163),
#  ('only', 1.3873517786561265),
#  ('go', 1.381720430107527),
#  ('color.', 1.3737373737373737),
#  ('pink', 1.3695652173913044),
#  ('show', 1.3653846153846154),
#  ('wish', 1.358974358974359),
#  ('petite', 1.3553719008264462),
#  ('underneath', 1.3518518518518519),
#  ('decided', 1.3493975903614457),
#  ('lbs,', 1.3461538461538463),
#  ('size', 1.3449367088607596),
#  ('feels', 1.34),
#  ('waist,', 1.3333333333333333),
#  ('sale', 1.3274336283185841),
#  ('different', 1.3271028037383177),
#  ('tops', 1.3176470588235294),
#  ('flattering', 1.3161764705882353),
#  ('saw', 1.3154362416107384),
#  ('has', 1.314516129032258),
#  ('dresses', 1.3068181818181819),
#  ('wear.', 1.3061224489795917),
#  ('every', 1.3037974683544304),
#  ('usual', 1.2991452991452992),
#  ('may', 1.296),
#  ('makes', 1.2913907284768211),
#  ('sweater.', 1.2881355932203389),
#  ('(i', 1.2876712328767124),
#  ("it's", 1.2806067172264355),
#  ('went', 1.2805755395683454),
#  ('colors', 1.275),
#  ('between', 1.2747252747252746),
#  ('up', 1.2666666666666666),
#  ('full', 1.264367816091954),
#  ('probably', 1.2641509433962264),
#  ('normally', 1.264),
#  ('style.', 1.2549019607843137),
#  ('8', 1.25),
#  ('length.', 1.2452830188679245),
#  ('6', 1.2429906542056075),
#  ('knit', 1.2424242424242424),
#  ('xxs', 1.2391304347826086),
#  ('those', 1.234375),
#  ('are', 1.233754512635379),
#  ('lace', 1.231578947368421),
#  ('these', 1.2295081967213115),
#  ('pockets', 1.2264150943396226),
#  ('about', 1.224755700325733),
#  ('&', 1.2195121951219512),
#  ('This', 1.2181818181818183),
#  ("i'm", 1.2139107611548556),
#  ('its', 1.213740458015267),
#  ('am', 1.209142857142857),
#  ('usually', 1.2077922077922079),
#  ("i've", 1.205607476635514),
#  ('white', 1.2035928143712575),
#  ('last', 1.1967213114754098),
#  ('4', 1.1962616822429906),
#  ('does', 1.1956521739130435),
#  ('lot', 0.959349593495935),
#  ('fell', 0.9552238805970149),
#  ('because', 0.9536741214057508),
#  ('person', 0.9519230769230769),
#  ('style', 0.9502487562189055),
#  ('sure', 0.9493670886075949),
#  ('large,', 0.9491525423728814),
#  ('than', 0.9461279461279462),
#  ("don't", 0.9451612903225807),
#  ('take', 0.945054945054945),
#  ('extra', 0.9444444444444444),
#  ("that's", 0.9431818181818182),
#  ('another', 0.9407407407407408),
#  ('fine', 0.9393939393939394),
#  ('reviewers', 0.9382716049382716),
#  ('cute', 0.9333333333333333),
#  ('seems', 0.9326923076923077),
#  ('pretty', 0.9304635761589404),
#  ('know', 0.9285714285714286),
#  ('5', 0.9285714285714286),
#  ('them.', 0.926829268292683),
#  ('button', 0.9240506329113924),
#  ('quite', 0.9230769230769231),
#  ('while', 0.9194630872483222),
#  ('10', 0.9193548387096774),
#  ('get', 0.9164265129682997),
#  ('this', 0.9120634134258112),
#  ('sleeves', 0.9112903225806451),
#  ('online', 0.9081632653061225),
#  ('very', 0.9033942558746736),
#  ('never', 0.9),
#  ('keep', 0.8992248062015504),
#  ('slip', 0.8987341772151899),
#  ('.', 0.896551724137931),
#  ("doesn't", 0.8944723618090452),
#  ('have', 0.8891752577319587),
#  ('agree', 0.8870967741935484),
#  ('lining', 0.8857142857142857),
#  ('retailer', 0.8855218855218855),
#  ('small', 0.882943143812709),
#  ('time', 0.8805970149253731),
#  ('fit,', 0.88),
#  ('worth', 0.8796992481203008),
#  ('larger', 0.8791208791208791),
#  ('since', 0.8775510204081632),
#  ('an', 0.8729446935724963),
#  ('it,', 0.8727272727272727),
#  ('side', 0.8723404255319149),
#  ('it', 0.8676804054955315),
#  ('through', 0.8642857142857143),
#  ('curvy', 0.8636363636363636),
#  ('I', 0.8633575013943112),
#  ('pattern', 0.8601398601398601),
#  ('almost', 0.8571428571428571),
#  ('said', 0.8571428571428571),
#  ('good', 0.8554216867469879),
#  ('shirt.', 0.8536585365853658),
#  ('sizing', 0.8518518518518519),
#  ('reviewer', 0.8513513513513513),
#  ('your', 0.8491379310344828),
#  ('low', 0.8478260869565217),
#  ('looking', 0.8391959798994975),
#  ('sheer', 0.8378378378378378),
#  ('looks', 0.8369747899159664),
#  ('waist', 0.8360655737704918),
#  ('under', 0.8333333333333334),
#  ('around', 0.8325991189427313),
#  ('color,', 0.8311688311688312),
#  ('shorter', 0.8305084745762712),
#  ('sweater', 0.8283378746594006),
#  ('make', 0.8277511961722488),
#  ('by', 0.8253968253968254),
#  ('reference,', 0.8245614035087719),
#  ('all', 0.8225469728601252),
#  ('few', 0.822429906542056),
#  ('see', 0.8214285714285714),
#  ('me', 0.8205445544554455),
#  ('ordered', 0.818639798488665),
#  ('the', 0.8175201123738987),
#  ('try', 0.8157894736842105),
#  ('might', 0.8157894736842105),
#  ('overall', 0.8157894736842105),
#  ('one.', 0.8125),
#  ('big.', 0.8105263157894737),
#  ('took', 0.8072289156626506),
#  ('of', 0.8025946704067322),
#  ('price', 0.802547770700637),
#  ('large', 0.7987804878048781),
#  ('person.', 0.797752808988764),
#  ('really', 0.7954545454545454),
#  ('but', 0.7936553300943127),
#  ('neckline', 0.7931034482758621),
#  ('on', 0.7917532917532918),
#  ('shoulders', 0.7894736842105263),
#  ('hit', 0.7849462365591398),
#  ('tried', 0.7819383259911894),
#  ('neck', 0.7787610619469026),
#  ('tight', 0.7763713080168776),
#  ('below', 0.7714285714285715),
#  ('it.', 0.7692307692307693),
#  ('top,', 0.7669172932330827),
#  ('smaller', 0.7608695652173914),
#  ("isn't", 0.7603305785123967),
#  ('at', 0.7602674307545367),
#  ('thing', 0.7586206896551724),
#  ('anything', 0.7575757575757576),
#  ('just', 0.756734693877551),
#  ('out', 0.7544802867383512),
#  ('on.', 0.7539267015706806),
#  ('small,', 0.7529411764705882),
#  ('body', 0.7527472527472527),
#  ('--', 0.75),
#  ("there's", 0.75),
#  ('high', 0.7465437788018433),
#  ('should', 0.7463768115942029),
#  ('seem', 0.7428571428571429),
#  ('kind', 0.7407407407407407),
#  ('straight', 0.7377049180327869),
#  ('this.', 0.734375),
#  ('if', 0.728538283062645),
#  ('buttons', 0.7254901960784313),
#  ('once', 0.7252747252747253),
#  ('could', 0.7242152466367713),
#  ('top', 0.7231833910034602),
#  ('me,', 0.7164179104477612),
#  ('off', 0.7155963302752294),
#  ('quality', 0.7146401985111662),
#  ('several', 0.7142857142857143),
#  ('wash', 0.7126436781609196),
#  ('work', 0.7081081081081081),
#  ('bottom', 0.7061611374407583),
#  ('sizes', 0.7029702970297029),
#  ('material.', 0.7),
#  ('dress,', 0.6986301369863014),
#  ('bust', 0.6975308641975309),
#  ('also', 0.6921529175050302),
#  ('from', 0.6895074946466809),
#  ('online,', 0.6885245901639344),
#  ('like', 0.687200956937799),
#  ('front', 0.6864406779661016),
#  ('better', 0.6859903381642513),
#  ('first', 0.6846846846846847),
#  ('when', 0.6837725381414702),
#  ('something', 0.6824324324324325),
#  ('why', 0.6794871794871795),
#  ('tall', 0.6781609195402298),
#  ('fabric,', 0.6770833333333334),
#  ('short', 0.6731391585760518),
#  ('their', 0.6712328767123288),
#  ('price.', 0.6698113207547169),
#  ('fabric.', 0.6666666666666666),
#  ('chest', 0.6627218934911243),
#  ('such', 0.6616541353383458),
#  ('blouse', 0.6590909090909091),
#  ('liked', 0.6538461538461539),
#  ('reviews', 0.6503496503496503),
#  ('fabric', 0.6494427558257345),
#  ('kept', 0.647887323943662),
#  ('came', 0.6456692913385826),
#  ('big', 0.6446886446886447),
#  ('not', 0.6444256756756757),
#  ('trying', 0.6413043478260869),
#  ('beautiful,', 0.6410256410256411),
#  ('two', 0.6397849462365591),
#  ('inches', 0.6388888888888888),
#  ('making', 0.6376811594202898),
#  ('same', 0.6363636363636364),
#  ('before', 0.6344086021505376),
#  ('cut', 0.6257142857142857),
#  ('design', 0.6254295532646048),
#  ('would', 0.6199233716475095),
#  ('part', 0.6190476190476191),
#  ('heavy', 0.6190476190476191),
#  ('body.', 0.6176470588235294),
#  ('model.', 0.6153846153846154),
#  ('after', 0.610236220472441),
#  ('too', 0.6102189781021898),
#  ('pull', 0.6081081081081081),
#  ('look', 0.6065388951521984),
#  ('back', 0.604735883424408),
#  ('online.', 0.6021505376344086),
#  ('shirt', 0.6003937007874016),
#  ('problem', 0.6),
#  ("wouldn't", 0.5980392156862745),
#  ('line', 0.5972222222222222),
#  ('wide', 0.5918367346938775),
#  ('arms', 0.5901639344262295),
#  ('material', 0.5896551724137931),
#  ('no', 0.5889423076923077),
#  ('where', 0.583941605839416),
#  ('then', 0.5792079207920792),
#  ('had', 0.5765247410817032),
#  ('quality.', 0.5760869565217391),
#  ('coat', 0.5753424657534246),
#  ('hips', 0.5638297872340425),
#  ('what', 0.5637583892617449),
#  ('already', 0.5625),
#  ('put', 0.5595238095238095),
#  ('least', 0.5591397849462365),
#  ('zipper', 0.5578947368421052),
#  ("wasn't", 0.5572916666666666),
#  ('been', 0.5508982035928144),
#  ('much', 0.5489296636085627),
#  ('across', 0.5483870967741935),
#  ('who', 0.5471698113207547),
#  ('even', 0.5443686006825939),
#  ('shape', 0.5412371134020618),
#  ('on,', 0.5396825396825397),
#  ('work.', 0.5393258426966292),
#  ('hoping', 0.5360824742268041),
#  ('shown', 0.5352112676056338),
#  ('did', 0.5341463414634147),
#  ('extremely', 0.5333333333333333),
#  ('picture', 0.5307692307692308),
#  ('rather', 0.5287356321839081),
#  ('way.', 0.524390243902439),
#  ('however', 0.5238095238095238),
#  ('made', 0.5188470066518847),
#  ('ran', 0.5157894736842106),
#  ('there', 0.5137614678899083),
#  ('loved', 0.5133531157270029),
#  ('cute,', 0.5),
#  ('however,', 0.4984126984126984),
#  ('area', 0.49107142857142855),
#  ('model', 0.4898989898989899),
#  ('short.', 0.4875),
#  ('arm', 0.48739495798319327),
#  ('shape.', 0.4782608695652174),
#  ('The', 0.4716981132075472),
#  ("didn't", 0.45255474452554745),
#  ('thought', 0.4523809523809524),
#  ('going', 0.45038167938931295),
#  ('thin', 0.4495798319327731),
#  ('me.', 0.43567753001715265),
#  ('was', 0.42629289511841467),
#  ('boxy', 0.4233576642335766),
#  ("couldn't", 0.41875),
#  ('way', 0.41760299625468167),
#  ('picture.', 0.4105263157894737),
#  ('photo', 0.3939393939393939),
#  ('maybe', 0.3924731182795699),
#  ('suit', 0.3918918918918919),
#  ('all.', 0.3888888888888889),
#  ('were', 0.38461538461538464),
#  ('someone', 0.375),
#  ('arrived', 0.375),
#  ('holes', 0.37),
#  ('expected', 0.3493975903614458),
#  ('felt', 0.34782608695652173),
#  ('washed', 0.34074074074074073),
#  ('nothing', 0.3247863247863248),
#  ('also,', 0.31932773109243695),
#  ('bad', 0.30392156862745096),
#  ('return', 0.27547169811320754),
#  ('off.', 0.2711864406779661),
#  ('looked', 0.2706896551724138),
#  ('wanted', 0.2595078299776286),
#  ('seemed', 0.2459016393442623),
#  ('back.', 0.232),
#  ('unfortunately', 0.2303370786516854),
#  ('completely', 0.22772277227722773),
#  ('returned', 0.21568627450980393),
#  ('sadly', 0.21568627450980393),
#  ('hung', 0.21428571428571427),
#  ('returning', 0.20652173913043478),
#  ('lay', 0.2),
#  (17480, 98),
#  (17571, 98),
#  (17876, 98),
#  (18315, 98),
#  (18599, 98),
#  (18929, 98),
#  (19108, 98),
#  (19283, 98),
#  (19588, 98),
#  (20103, 98),
#  (21114, 98),
#  (21641, 98),
#  (21673, 98),
#  (21931, 98),
#  (22237, 98),
#  (22467, 98),
#  (22510, 98),
#  (4449, 97),
#  (410, 97),
#  (23118, 97),
#  (4770, 97),
#  (13111, 97),
#  (11637, 97),
#  (4620, 97),
#  (1477, 97),
#  (748, 97),
#  (19520, 97),
#  (22060, 97),
#  (2970, 97),
#  (18379, 97),
#  (6507, 97),
#  (21033, 97),
#  (15102, 97),
#  (21422, 97),
#  (10387, 97),
#  (13178, 97),
#  (2545, 97),
#  (18017, 97),
#  (6039, 97),
#  (15072, 97),
#  (8851, 97),
#  (1210, 97),
#  (16673, 97),
#  (8312, 97),
#  (5447, 97),
#  (415, 97),
#  (23026, 97),
#  (13578, 97),
#  (12058, 97),
#  (21870, 97),
#  (20720, 97),
#  (6278, 97),
#  (18470, 97),
#  (15315, 97),
#  (14476, 97),
#  (12041, 97),
#  (18537, 97),
#  (11890, 97),
#  (7454, 97),
#  (17073, 97),
#  (16949, 97),
#  (17126, 97),
#  (3884, 97),
#  (10980, 97),
#  (7301, 97),
#  (13760, 97),
#  (4698, 97),
#  (22373, 97),
#  (12550, 97),
#  (22797, 97),
#  (10121, 97),
#  (6089, 97),
#  (5038, 97),
#  (228, 97),
#  (19362, 97),
#  (1686, 97),
#  (324, 97),
#  (4392, 97),
#  (18658, 97),
#  (11897, 97),
#  (22951, 97),
#  (23185, 97),
#  (5982, 97),
#  (431, 97),
#  (5194, 97),
#  (262, 97),
#  (447, 97),
#  (475, 97),
#  (948, 97),
#  (955, 97),
#  (1098, 97),
#  (1367, 97),
#  (1618, 97),
#  (1755, 97),
#  (1809, 97),
#  (2311, 97),
#  (2734, 97),
#  (2786, 97),
#  (2873, 97),
#  (3197, 97),
#  ...]

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# We will clean punctuations from all the review text

# %%
from string import punctuation

# %%
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def remove_punctuation(txt):
    for p in punctuation:
        txt = txt.replace(p, '')
    
    # also remove \n and \r
    txt = txt.replace('\n', '')
    txt = txt.replace('\r', '')
    return txt

# %%
df_2['Review Text'] = df_2['Review Text'].apply(remove_punctuation)

# %%
import nltk
from nltk.corpus import stopwords

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/grandia/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
stopwords.words('english')
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
def remove_stopwords(txt):
    cleaned_text = []
    stops = stopwords.words('english')
    # 'I' seems to be missing
    stops.append('I')
    for word in txt.split():
        if word not in stops:
            cleaned_text.append(word)
    
    text = ' '.join(cleaned_text)
        
    return text

# %%
df_2['Review Text'] = df_2['Review Text'].apply(remove_stopwords)

# %% [markdown]
# ### Word Encoding

# %%
## build vocab dictionary
combined_text = df_2['Review Text'].str.cat(sep=' ')
words = combined_text.split()

# %%
counts = Counter(words)

# %%
len(counts)
# Out:
# 12524

# %%
# sort the vocab based on counts, so that most common word has lower int representation
vocab = sorted(counts, key=counts.get, reverse=True)

# %%
# start the coding with 1, since we will use 0 for padding
vocab_to_int = {word: ii for ii, word in enumerate(vocab, 1)}

# %%
df_3 = df_2.copy()

# %%
# transform each review text to int representation
df_3['Review Text Int'] = df_3['Review Text'].apply(lambda x: [vocab_to_int[word] for word in x.split()])

# %%
def pad_with_zeros(x):
    return_list = [0] * 113
    count_left_zero = 113 - len(x)
    for idx, word_int in enumerate(x):
        return_list[idx + count_left_zero] = word_int
    
    return return_list

# %%
# left pad reviews that are less than 113 words with 0s
df_3['Review Text Int'] = df_3['Review Text Int'].apply(pad_with_zeros)

# %%
df_3['Review Text Int'] = df_3['Review Text Int'].apply(lambda x: np.array(x))

# %% [markdown]
# ## Train and Test Set

# %%
from sklearn.model_selection import train_test_split

# %%
# convert from array of arrays to 2D array
X = np.stack(df_3['Review Text Int'].as_matrix())
y = df_3['Recommended IND']
# Out:
# /Users/grandia/anaconda3/envs/pysyft/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y)

# %% [markdown]
# ## Neural Network

# %%
from keras.models import Sequential
from keras.layers import LSTM, Embedding, Dense
# Out:
# Using TensorFlow backend.

# %%
lstm_size = 113
embed_size = 400

# %%
model = Sequential()
model.add(Embedding(len(counts)+1, embed_size, input_length=113))
model.add(LSTM(lstm_size))
model.add(Dense(1, activation='sigmoid'))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0926 09:09:21.468464 4582794688 deprecation_wrapper.py:119] From /Users/grandia/anaconda3/envs/pysyft/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0926 09:09:21.544189 4582794688 deprecation_wrapper.py:119] From /Users/grandia/anaconda3/envs/pysyft/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0926 09:09:21.548192 4582794688 deprecation_wrapper.py:119] From /Users/grandia/anaconda3/envs/pysyft/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.

# %%
model.compile(loss='binary_crossentropy', optimizer='adam')
# Out:
# W0926 09:09:22.034910 4582794688 deprecation_wrapper.py:119] From /Users/grandia/anaconda3/envs/pysyft/lib/python3.7/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0926 09:09:22.090688 4582794688 deprecation_wrapper.py:119] From /Users/grandia/anaconda3/envs/pysyft/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3376: The name tf.log is deprecated. Please use tf.math.log instead.
#
# W0926 09:09:22.110435 4582794688 deprecation.py:323] From /Users/grandia/anaconda3/envs/pysyft/lib/python3.7/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
model.fit(X_train, y_train,
          batch_size=128,
          epochs=3)
# Out:
# W0926 09:09:26.104203 4582794688 deprecation_wrapper.py:119] From /Users/grandia/anaconda3/envs/pysyft/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Epoch 1/3
# 6561/6561 [==============================] - 30s 5ms/step - loss: 0.5040
# Epoch 2/3
# 6561/6561 [==============================] - 44s 7ms/step - loss: 0.2533
# Epoch 3/3
# 6561/6561 [==============================] - 33s 5ms/step - loss: 0.1648

# %%
y_pred = model.predict(X_test)

# %%
y_pred = y_pred >= 0.5

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.8427787934186471

# %%
model.save('lstm.h5')

# %%
import pickle

# %%
pickle.dump(vocab_to_int, open('vocab_to_int.pickle', 'wb'))

# %%
vocab_loaded = pickle.load(open('vocab_to_int.pickle', 'rb'))

# %%
review = "i love this dress sooooo much"

# %%
review.split()
# Out:
# ['i', 'love', 'this', 'dress', 'sooooo', 'much']

# %%
# remove word not in vocab
new_review = [word for word in review.split() if word in vocab_to_int]

# %%
integered = [vocab_to_int[word] for word in new_review]

# %%
padded = pad_with_zeros(integered)

# %%
reshaped = np.array(padded).reshape(1,-1)

# %%
model.predict(reshaped)
# Out:
# array([[0.48872632]], dtype=float32)

# %%
from keras.models import load_model

# %%
model2 = load_model('lstm.h5')

# %%
res = model.predict(reshaped)

# %%
res[0][0]
# Out:
# 0.48872632
